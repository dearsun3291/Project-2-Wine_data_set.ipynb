# %% [markdown]
# # Project 2 Wine Data set

# %% [markdown]
# Objective - Develop a model to predict class of wine i.e amoung 1 or 2 or 3 based on provided characteristics
#
# Target variable is class and since target categories are 'THREE' , hence classification approach is more suitable

# %% [markdown]
# # Import Libraries

# %%
#import required libraries
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading dataset

# %%
#loading/importing dataset
wne = pd.read_csv('winedataset.csv')

# %%
wne.head(10)
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
# 5      1    14.20        1.76  2.45               15.2        112
# 6      1    14.39        1.87  2.45               14.6         96
# 7      1    14.06        2.15  2.61               17.6        121
# 8      1    14.83        1.64  2.17               14.0         97
# 9      1    13.86        1.35  2.27               16.0         98
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# ...

# %% [markdown]
# # Data Prepration

# %%
wne.shape
# Out:
# (178, 14)

# %%
wne.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %% [raw]
# # 1. Proline has highest standard deviation i.e data is very much spread
# # 2. Mean is greater than median for most of the properties & difference is not significant.

# %%
wne.keys()
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
wne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  diluted wines         178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %% [raw]
# # No null values are present
# # All data is in numeric format (float or int)

# %%
wne.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
wne.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
wne.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %% [raw]
# Columns Malic acid, Magnesium has significantly higher skewness (greater than +/-0.5)

# %%
wne.nunique()
# Out:
# Class                     3
# Alcohol                 126
# Malic acid              133
# Ash                      79
# Alcalinity of ash        63
# Magnesium                53
# Total phenols            97
# Flavanoids              132
# Nonflavanoid phenols     39
# Proanthocyanins         101
# Color intensity         132
# Hue                      78
# diluted wines           122
# Proline                 121
# dtype: int64

# %% [markdown]
# # EDA Process

# %% [markdown]
# Univeriate analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
collist = wne.columns.values
for i in range(0,len(collist)):
    plt.figure(figsize = (5,40))
    plt.subplot(14,1,i+1)
    sns.distplot(wne[collist[i]])
    plt.show()

# %%
collist = wne.columns.values
for i in range(0,len(collist)):
    plt.figure(figsize = (5,80))
    plt.subplot(14,1,i+1)
    sns.boxplot(wne[collist[i]], orient = 'h', palette = 'Set1')
    plt.show()

# %% [raw]
# Malic Acid, Ash, Alcalinity of ash, Magnesium,Proanthacyanins,Color intensity,Hue shows some outliers

# %% [markdown]
# Biveriate analysis

# %%
plt.figure(figsize = (10,8))
sns.heatmap(wne.corr(), annot = True)
plt.title('Correlation mapping')
plt.show()

# %%
# Ash has very low negative coorelation & may be droped

# %% [markdown]
# # Data Cleaning

# %%
import scipy
from scipy.stats import zscore
z = np.abs(zscore(wne))
new = np.where(z >3)
new
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64),
#  array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
threshold = 3
new_wne = wne[(z<3).all(axis=1)]

# %%
new_wne
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
new_wne.skew() # Rechecking skewness
# Out:
# Class                   0.117053
# Alcohol                -0.028038
# Malic acid              0.966253
# Ash                    -0.250438
# Alcalinity of ash       0.104774
# Magnesium               0.566522
# Total phenols           0.132108
# Flavanoids             -0.077205
# Nonflavanoid phenols    0.481810
# Proanthocyanins         0.360217
# Color intensity         0.732580
# Hue                    -0.137430
# diluted wines          -0.282514
# Proline                 0.744773
# dtype: float64

# %%
# Still skewness is present in Magnesium,Colour intensity and Proline which is ignorable

# %%
plt.figure(figsize = (10,8))
sns.heatmap(new_wne.corr(), annot = True)
plt.title('Correlation mapping')
plt.show()

# %%
# Correlation have imporved though negligible.
# Malic acid, Alcalinity of ash,Nonflavanoid phenols,Color intensity are positively coorelated where as rest are negatively coorelated

# %% [markdown]
# # Building Model

# %%
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report, roc_curve,roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score

# %%
x = new_wne.iloc[:,1:-1]
y = new_wne.iloc[:,0]

# %%
x.shape
# Out:
# (168, 12)

# %%
y.shape
# Out:
# (168,)

# %%
# To find the best random state
best_r_state = 0
accu = 0
for i in range (30,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .31, random_state = i)
    svc =SVC(kernel = 'poly')
    svc.fit(x_train,y_train)
    predsvc = svc.predict(x_test)
    svc.score(x_train,y_train)
    tempaccu = accuracy_score(y_test,predsvc)
    if tempaccu > accu:
        accu = tempaccu
        best_r_state = i
    
    
print(f'For accuracy is {accu * 100}% best random state is {best_r_state}')
# Out:
# For accuracy is 73.58490566037736% best random state is 49

# %%
# Check best model at arrived random state

# %%
model = [SVC(kernel = 'poly'), SVC(kernel = 'rbf'), SVC(kernel = 'linear'),KNeighborsClassifier(),DecisionTreeClassifier(),  MultinomialNB(), GaussianNB()]
for m in model:
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .31, random_state = 49)
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    mpred = m.predict(x_test)
    ack=accuracy_score(y_test,mpred)
    cvscore = cross_val_score(m,x,y,cv = 5).mean()
    print(f'accuracy is {ack *100}% & cross_val Score is {cvscore} for model {m}')
# Out:
# accuracy is 73.58490566037736% & cross_val Score is 0.6203208556149733 for model SVC(kernel='poly')
# accuracy is 67.9245283018868% & cross_val Score is 0.5602495543672015 for model SVC()
# accuracy is 100.0% & cross_val Score is 0.9408199643493761 for model SVC(kernel='linear')
# accuracy is 84.90566037735849% & cross_val Score is 0.8276292335115863 for model KNeighborsClassifier()
# accuracy is 94.33962264150944% & cross_val Score is 0.8939393939393939 for model DecisionTreeClassifier()
# accuracy is 94.33962264150944% & cross_val Score is 0.8880570409982174 for model MultinomialNB()
# accuracy is 96.22641509433963% & cross_val Score is 0.9285204991087344 for model GaussianNB()

# %% [markdown]
# # Conclusion - Best accuracy of 100% is acheived with SVC (Kernel = 'linear')

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .31, random_state = 49)
svc = SVC(kernel = 'linear')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
svcpred = svc.predict(x_test)
ack=accuracy_score(y_test,svcpred)
cvscore = cross_val_score(svc,x,y,cv = 5).mean()
print(f'accuracy is {ack *100}% & cross_val Score is {cvscore} the difference is  {ack - cvscore}')
print(confusion_matrix(y_test,svcpred))
print(classification_report(y_test,svcpred))
# Out:
# accuracy is 100.0% & cross_val Score is 0.9408199643493761 the difference is  0.05918003565062391
# [[17  0  0]
#  [ 0 24  0]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        24
#            3       1.00      1.00      1.00        12
#
#     accuracy                           1.00        53
#    macro avg       1.00      1.00      1.00        53
# weighted avg       1.00      1.00      1.00        53

# %% [markdown]
# # Serialization

# %%
import joblib

# %%
joblib.dump(svc,'Project_2_wine_dataset.pkl')
# Out:
# ['Project_2_wine_dataset.pkl']

# %%
sk2 =joblib.load('Project_2_wine_dataset.pkl')

# %%
sk2
# Out:
# SVC(kernel='linear')
